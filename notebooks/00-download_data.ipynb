# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/atlantico-academy/datasets/main/mpg.csv")
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.to_csv("../data/raw/data.csv", index=False)

# %%
dicionario = pd.DataFrame([
    {
        "variável": "mpg",
        "descrição": "milhas percorridas por galão de combustível",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variável": "cylinders",
        "descrição": "quantidade de cilindros no motor do veículo",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variável": "displacement",
        "descrição": "cilindrada do motor em centímetros cúbicos (cc)",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variável": "horsepower",
        "descrição": "potência do motor em cavalos de potência (hp)",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variável": "weight",
        "descrição": "peso total do veículo em libras (lbs)",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variável": "acceleration",
        "descrição": "aceleração do veículo (km/h)",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variável": "model_year",
        "descrição": "ano de fabricação do veículo",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variável": "origin",
        "descrição": "local de fabricação do veículo",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variável": "name",
        "descrição": "nome comercial do veículo",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },
])
dicionario.to_csv('../data/external/dictionary.csv', index=False)
dicionario
# Out:
#        variável                                        descrição  \
# 0           mpg      milhas percorridas por galão de combustível
# 1     cylinders      quantidade de cilindros no motor do veículo
# 2  displacement  cilindrada do motor em centímetros cúbicos (cc)
# 3    horsepower    potência do motor em cavalos de potência (hp)
# 4        weight            peso total do veículo em libras (lbs)
# 5  acceleration                     aceleração do veículo (km/h)
# 6    model_year                     ano de fabricação do veículo
# 7        origin                   local de fabricação do veículo
# 8          name                        nome comercial do veículo
#
#            tipo   subtipo
# 0  quantitativa  contínua
# 1  quantitativa  discreta
# 2  quantitativa  contínua
# 3  quantitativa  contínua
# 4  quantitativa  contínua
# 5  quantitativa  contínua
# 6  quantitativa  discreta
# 7   qualitativa   nominal
# 8   qualitativa   nominal
